# %% [markdown]
# ## Stream Processing Arquitectura Completa

# %% [markdown]
# Goals:
#
# * Perform a realtime stock prices analytics
# * For this we use two data sources
#     * [IEX Cloud](https://iexcloud.io/)
#     * [Twitter](https://developer.twitter.com/)
# * We implement following data pipeline
#     * Data Ingestion in Nifi and Kafka
#     * Data processing with Spark Streaming
#     * Data Storage on Elasticsearch
#     * Data visualization on Kibana

# %% [markdown]
# Let’s create a data processing for Stock prices

# %%
import sys
import json
import pprint
from pyspark import SparkContext
from pyspark import SparkConf
from pyspark.streaming import StreamingContext

from pyspark.streaming.kafka import KafkaUtils

conf = SparkConf().setAll([("es.index.auto.create", "true")])

sc = SparkContext(appName="QuotesConsumer",conf=conf)
ssc = StreamingContext(sc, 1)

kafkaParams = {'bootstrap.servers': 'broker:29092', 'group.id' : 'quotesConsumer'}
topicQuotes = ['quotes']

streamQuotes = KafkaUtils.createDirectStream(ssc, topicQuotes, kafkaParams)

# %% [markdown]
# Load companies Json reference on a dictionary

# %%
with open('/tmp/data/companies.json') as json_file:
    Lines = json_file.readlines()
    
companies = { }
# Parse compnies data
for line in Lines: 
    data = json.loads(line) 
    companies[data["symbol"]]=data

# %% [markdown]
# Create an enrichment function to add company data to every input quote

# %%
def enrichQuote(quote, companies):
    quoteJson=json.loads(quote[1])    
    companyJson=companies[quoteJson["symbol"]]
    quoteJson.update(companyJson) 
    return(quote[0],json.dumps(quoteJson))

# %% [markdown]
# Now apply a map to add this company reference fields

# %%
streamQuotesEnriched=streamQuotes.map(lambda record : enrichQuote(record,companies) )                                   
    
streamQuotesEnriched.map(lambda record : (record[0], record[1])).pprint()

# %% [markdown]
# Finally we add a sink to store on elastic

# %%
es_write_quotes = {
        "es.nodes" : "elasticsearch",
        "es.port" : "9200",
        "es.resource" : 'quotes/_doc',
        "es.input.json": "yes",
    }


streamQuotesEnriched.foreachRDD(lambda rdd: rdd.saveAsNewAPIHadoopFile(
        path='-',
        outputFormatClass="org.elasticsearch.hadoop.mr.EsOutputFormat",
        keyClass="org.apache.hadoop.io.NullWritable",
        valueClass="org.elasticsearch.hadoop.mr.LinkedMapWritable",
        conf=es_write_quotes))

# %% [markdown]
# Let’s create a data processing for twitter

# %%
topicTwitter = ['tweets']

streamTwitter = KafkaUtils.createDirectStream(ssc, topicTwitter, kafkaParams)

streamTwitter.map(lambda record : (record[0], record[1])).pprint()


es_write_twitter = {
        "es.nodes" : "elasticsearch",
        "es.port" : "9200",
        "es.resource" : 'tweets/_doc',
        "es.input.json": "yes",
    }

streamTwitter.foreachRDD(lambda rdd: rdd.saveAsNewAPIHadoopFile(
        path='-',
        outputFormatClass="org.elasticsearch.hadoop.mr.EsOutputFormat",
        keyClass="org.apache.hadoop.io.NullWritable",
        valueClass="org.elasticsearch.hadoop.mr.LinkedMapWritable",
        conf=es_write_twitter))

# %% [markdown]
# Finally let's launch the process

# %%
ssc.start()
ssc.awaitTermination()
# Out:
# -------------------------------------------
# Time: 2021-01-19 15:07:10
# -------------------------------------------
# (None, '{"symbol": "AAPL", "companyName": "Apple, Inc.", "primaryExchange": "D TAAALLCNG(ON/ ARSTGQSEE LMK)SBE", "calculationPrice": "tops", "open": null, "openTime": null, "openSource": "foiciafl", "close": null, "closeTime": null, "closeSource": "olfiiafc", "high": null, "highTime": null, "highSource": null, "low": null, "lowTime": 1658590760686, "lowSource": "rEiicltpmee eaXI  r", "latestPrice": 131.69, "latestSource": "IEX real time price", "latestTime": "10:06:53 AM", "latestUpdate": 1623864662616, "latestVolume": null, "iexRealtimePrice": 130.99, "iexRealtimeSize": 103, "iexLastUpdated": 1646033409507, "delayedPrice": null, "delayedPriceTime": null, "oddLotDelayedPrice": null, "oddLotDelayedPriceTime": null, "extendedPrice": null, "extendedChange": null, "extendedChangePercent": null, "extendedPriceTime": null, "previousClose": 132.78, "previousVolume": 117127317, "change": 0.03, "changePercent": 0.00024, "volume": null, "iexMarketPercent": 0.00833691763394616, "iexVolume": 220852, "avgTotalVolume": 111413820, "iexBidPrice": 127, "iexBidSize": 102, "iexAskPrice": 131, "iexAskSize": 102, "iexOpen": null, "iexOpenTime": null, "iexClose": 127.33, "iexCloseTime": 1619220815117, "marketCap": 2171953926969, "peRatio": 40.37, "week52High": 143.47, "week52Low": 57.23, "ytdChange": -0.04308366332419372, "lastTradeTime": 1634805873967, "isUSMarketOpen": true, "exchange": "NASDAQ", "industry": "Telecommunications Equipment", "website": "http://www.apple.com", "description": "Apple, Inc. engages in the design, manufacture, and marketing of mobile communication, media devices, personal computers, and portable digital music players. It operates through the following geographical segments: Americas, Europe, Greater China, Japan, and Rest of Asia Pacific. The Americas segment includes North and South America. The Europe segment consists of European countries, as well as India, the Middle East, and Africa. The Greater China segment comprises of China, Hong Kong, and Taiwan. The Rest of Asia Pacific segment includes Australia and Asian countries. The company was founded by Steven Paul Jobs, Ronald Gerald Wayne, and Stephen G. Wozniak on April 1, 1976 and is headquartered in Cupertino, CA.", "CEO": "Timothy Donald Cook", "securityName": "Apple Inc.", "issueType": "cs", "sector": "Electronic Technology", "employees": 132000, "tags": ["Electronic Technology", "Telecommunications Equipment"]}')
# (None, '{"symbol": "GOOG", "companyName": "Alphabet, Inc.", "primaryExchange": "T/MO AQLAELS CEKA ARNT(GBEDLSSN)G", "calculationPrice": "tops", "open": null, "openTime": null, "openSource": "faiilofc", "close": null, "closeTime": null, "closeSource": "lficafoi", "high": null, "highTime": null, "highSource": null, "low": null, "lowTime": 1664772984280, "lowSource": "ai ipEet ecImeXrl r", "latestPrice": 1788.79, "latestSource": "IEX real time price", "latestTime": "10:06:55 AM", "latestUpdate": 1624431043689, "latestVolume": null, "iexRealtimePrice": 1812.22, "iexRealtimeSize": 105, "iexLastUpdated": 1669754560665, "delayedPrice": null, "delayedPriceTime": null, "oddLotDelayedPrice": null, "oddLotDelayedPriceTime": null, "extendedPrice": null, "extendedChange": null, "extendedChangePercent": null, "extendedPriceTime": null, "previousClose": 1804.38, "previousVolume": 1371407, "change": 18.8, "changePercent": 0.01044, "volume": null, "iexMarketPercent": 0.0643522979452478, "iexVolume": 16123, "avgTotalVolume": 1439714, "iexBidPrice": 1788.02, "iexBidSize": 102, "iexAskPrice": 1808.29, "iexAskSize": 102, "iexOpen": 1815.23, "iexOpenTime": 1622677693181, "iexClose": 1836.75, "iexCloseTime": 1655344158830, "marketCap": 1218278613676, "peRatio": null, "week52High": 1911.99, "week52Low": 1097, "ytdChange": 0.0014052962076216461, "lastTradeTime": 1637195603832, "isUSMarketOpen": true, "exchange": "NASDAQ", "industry": "Internet Software/Services", "website": "http://abc.xyz", "description": "Alphabet, Inc. is a holding company, which engages in the business of acquisition and operation of different companies. It operates through the Google and Other Bets segments. The Google segment includes its main Internet products such as Ads, Android, Chrome, Commerce, Google Cloud, Google Maps, Google Play, Hardware, Search, and YouTube. The Other Bets segment includes businesses such as Access, Calico, CapitalG, GV, Nest, Verily, Waymo, and X. The company was founded by Lawrence E. Page and Sergey Mikhaylovich Brin on October 2, 2015 and is headquartered in Mountain View, CA.", "CEO": "Lawrence E. Page", "securityName": "Alphabet Inc. Class C", "issueType": "cs", "sector": "Technology Services", "employees": 98771, "tags": ["Technology Services", "Internet Software/Services"]}')
# (None, '{"symbol": "ORCL", "companyName": "Oracle Corp.", "primaryExchange": "TSXYAHCO R  .CNK EEWKIOENN,GC", "calculationPrice": "tops", "open": null, "openTime": null, "openSource": "fcailifo", "close": null, "closeTime": null, "closeSource": "fifioacl", "high": null, "highTime": 1657025324422, "highSource": "de cer5a1delteuni my pi", "low": null, "lowTime": 1640573467783, "lowSource": "aem c rrXEielit Ipe", "latestPrice": 64.34, "latestSource": "IEX real time price", "latestTime": "10:06:38 AM", "latestUpdate": 1665060078506, "latestVolume": null, "iexRealtimePrice": 62.31, "iexRealtimeSize": 101, "iexLastUpdated": 1673067661855, "delayedPrice": null, "delayedPriceTime": null, "oddLotDelayedPrice": null, "oddLotDelayedPriceTime": null, "extendedPrice": null, "extendedChange": null, "extendedChangePercent": null, "extendedPriceTime": null, "previousClose": 64.2, "previousVolume": 7561083, "change": -0.14, "changePercent": -0.0022, "volume": null, "iexMarketPercent": 0.01558521341812165, "iexVolume": 27185, "avgTotalVolume": 9245266, "iexBidPrice": 62.73, "iexBidSize": 418, "iexAskPrice": 0, "iexAskSize": 0, "iexOpen": 64.04, "iexOpenTime": 1690650071060, "iexClose": 62.87, "iexCloseTime": 1649347518391, "marketCap": 189808360005, "peRatio": 19.32, "week52High": 65.67, "week52Low": 39.42, "ytdChange": -0.04369841146057202, "lastTradeTime": 1669078959718, "isUSMarketOpen": true, "exchange": "New York Stock Exchange", "industry": "Packaged Software", "website": "http://www.oracle.com", "description": "Oracle Corp. engages in the provision of products and services that address all aspects of corporate information technology environments. It operates through the following business segments: Cloud and License, Hardware, and Services. The Cloud and License segment markets, sells, and delivers applications, platform, and infrastructure technologies. The Hardware segment provides hardware products and hardware-related software products including Oracle Engineered Systems, servers, storage, industry-specific hardware, operating systems, virtualization, management and other hardware related software, and related hardware support. The Services segment offers consulting, advanced support, and education services. The company was founded by Lawrence Joseph Ellison, Robert Nimrod Miner and Edward A. Oates on June 16, 1977 and is headquartered in Redwood City, CA.", "CEO": "Safra Ada Catz / Mark V. Hurd", "securityName": "Oracle Corporation", "issueType": "cs", "sector": "Technology Services", "employees": 136000, "tags": ["Technology Services", "Packaged Software"]}')
#
# -------------------------------------------
# Time: 2021-01-19 15:07:11
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:12
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:13
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:14
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:16
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:17
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:18
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:19
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:21
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:22
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:23
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:24
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:25
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:26
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:27
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:28
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:29
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:30
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:31
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:32
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:33
# -------------------------------------------
# (None, '{"symbol": "AAPL", "companyName": "Apple, Inc.", "primaryExchange": "SMKAES  TRATLDS GL(NQNG/LBACOE)EA", "calculationPrice": "tops", "open": null, "openTime": null, "openSource": "icflfoai", "close": null, "closeTime": null, "closeSource": "falcfiio", "high": null, "highTime": null, "highSource": null, "low": null, "lowTime": 1665896454287, "lowSource": "eX aEmelrtiIcir pe ", "latestPrice": 130.66, "latestSource": "IEX real time price", "latestTime": "10:07:30 AM", "latestUpdate": 1682970599881, "latestVolume": null, "iexRealtimePrice": 132.72, "iexRealtimeSize": 204, "iexLastUpdated": 1618802291125, "delayedPrice": null, "delayedPriceTime": null, "oddLotDelayedPrice": null, "oddLotDelayedPriceTime": null, "extendedPrice": null, "extendedChange": null, "extendedChangePercent": null, "extendedPriceTime": null, "previousClose": 128.1, "previousVolume": 113485511, "change": 0.05, "changePercent": 0.0004, "volume": null, "iexMarketPercent": 0.00835574139302701, "iexVolume": 219994, "avgTotalVolume": 111227119, "iexBidPrice": 132.61, "iexBidSize": 102, "iexAskPrice": 131.6, "iexAskSize": 102, "iexOpen": 127.24, "iexOpenTime": 1687718736598, "iexClose": 129.97, "iexCloseTime": 1646297604550, "marketCap": 2140027070669, "peRatio": 39.63, "week52High": 141.08, "week52Low": 57.55, "ytdChange": -0.04340535377262483, "lastTradeTime": 1659226473003, "isUSMarketOpen": true, "exchange": "NASDAQ", "industry": "Telecommunications Equipment", "website": "http://www.apple.com", "description": "Apple, Inc. engages in the design, manufacture, and marketing of mobile communication, media devices, personal computers, and portable digital music players. It operates through the following geographical segments: Americas, Europe, Greater China, Japan, and Rest of Asia Pacific. The Americas segment includes North and South America. The Europe segment consists of European countries, as well as India, the Middle East, and Africa. The Greater China segment comprises of China, Hong Kong, and Taiwan. The Rest of Asia Pacific segment includes Australia and Asian countries. The company was founded by Steven Paul Jobs, Ronald Gerald Wayne, and Stephen G. Wozniak on April 1, 1976 and is headquartered in Cupertino, CA.", "CEO": "Timothy Donald Cook", "securityName": "Apple Inc.", "issueType": "cs", "sector": "Electronic Technology", "employees": 132000, "tags": ["Electronic Technology", "Telecommunications Equipment"]}')
#
# -------------------------------------------
# Time: 2021-01-19 15:07:34
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:35
# -------------------------------------------
# (None, '{"symbol": "GOOG", "companyName": "Alphabet, Inc.", "primaryExchange": "DG(OLASE )QNSTSKAELL MAGCEAR /TBN", "calculationPrice": "tops", "open": null, "openTime": null, "openSource": "fciloafi", "close": null, "closeTime": null, "closeSource": "fociiafl", "high": null, "highTime": null, "highSource": null, "low": null, "lowTime": 1621644429615, "lowSource": "Ileerpt X Eimare ci", "latestPrice": 1775.55, "latestSource": "IEX real time price", "latestTime": "10:07:32 AM", "latestUpdate": 1657004682473, "latestVolume": null, "iexRealtimePrice": 1840.74, "iexRealtimeSize": 1, "iexLastUpdated": 1639470669314, "delayedPrice": null, "delayedPriceTime": null, "oddLotDelayedPrice": null, "oddLotDelayedPriceTime": null, "extendedPrice": null, "extendedChange": null, "extendedChangePercent": null, "extendedPriceTime": null, "previousClose": 1760.09, "previousVolume": 1381533, "change": 20.14, "changePercent": 0.0115, "volume": null, "iexMarketPercent": 0.06550276229590839, "iexVolume": 16950, "avgTotalVolume": 1449410, "iexBidPrice": 1806.89, "iexBidSize": 104, "iexAskPrice": 0, "iexAskSize": 0, "iexOpen": 1842.09, "iexOpenTime": 1670529109402, "iexClose": 1821.41, "iexCloseTime": 1688758289237, "marketCap": 1192228073789, "peRatio": null, "week52High": 1882.14, "week52Low": 1072.4, "ytdChange": 0.00219508379446836, "lastTradeTime": 1658818741820, "isUSMarketOpen": true, "exchange": "NASDAQ", "industry": "Internet Software/Services", "website": "http://abc.xyz", "description": "Alphabet, Inc. is a holding company, which engages in the business of acquisition and operation of different companies. It operates through the Google and Other Bets segments. The Google segment includes its main Internet products such as Ads, Android, Chrome, Commerce, Google Cloud, Google Maps, Google Play, Hardware, Search, and YouTube. The Other Bets segment includes businesses such as Access, Calico, CapitalG, GV, Nest, Verily, Waymo, and X. The company was founded by Lawrence E. Page and Sergey Mikhaylovich Brin on October 2, 2015 and is headquartered in Mountain View, CA.", "CEO": "Lawrence E. Page", "securityName": "Alphabet Inc. Class C", "issueType": "cs", "sector": "Technology Services", "employees": 98771, "tags": ["Technology Services", "Internet Software/Services"]}')
#
# -------------------------------------------
# Time: 2021-01-19 15:07:36
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:37
# -------------------------------------------
# (None, '{"symbol": "ORCL", "companyName": "Oracle Corp.", "primaryExchange": "ICA TK  R,HGENYN.SXE ECWONCKO", "calculationPrice": "tops", "open": null, "openTime": null, "openSource": "acfiilfo", "close": null, "closeTime": null, "closeSource": "fcoiialf", "high": null, "highTime": 1621886765316, "highSource": "ntdede ilacemypi15e ur ", "low": null, "lowTime": 1651940140234, "lowSource": "e rtEIeXi cepl mria", "latestPrice": 63.749, "latestSource": "IEX real time price", "latestTime": "10:07:36 AM", "latestUpdate": 1626670317181, "latestVolume": null, "iexRealtimePrice": 64.47, "iexRealtimeSize": 100, "iexLastUpdated": 1628744232399, "delayedPrice": null, "delayedPriceTime": null, "oddLotDelayedPrice": null, "oddLotDelayedPriceTime": null, "extendedPrice": null, "extendedChange": null, "extendedChangePercent": null, "extendedPriceTime": null, "previousClose": 62.11, "previousVolume": 7802751, "change": -0.138, "changePercent": -0.00226, "volume": null, "iexMarketPercent": 0.01574282721805542, "iexVolume": 28370, "avgTotalVolume": 9647341, "iexBidPrice": 62.82, "iexBidSize": 105, "iexAskPrice": 64.12, "iexAskSize": 100, "iexOpen": 64.101, "iexOpenTime": 1676254550419, "iexClose": 62.744, "iexCloseTime": 1683827046574, "marketCap": 181883901010, "peRatio": 19.28, "week52High": 65.91, "week52Low": 40.11, "ytdChange": -0.04373792125940237, "lastTradeTime": 1667367222217, "isUSMarketOpen": true, "exchange": "New York Stock Exchange", "industry": "Packaged Software", "website": "http://www.oracle.com", "description": "Oracle Corp. engages in the provision of products and services that address all aspects of corporate information technology environments. It operates through the following business segments: Cloud and License, Hardware, and Services. The Cloud and License segment markets, sells, and delivers applications, platform, and infrastructure technologies. The Hardware segment provides hardware products and hardware-related software products including Oracle Engineered Systems, servers, storage, industry-specific hardware, operating systems, virtualization, management and other hardware related software, and related hardware support. The Services segment offers consulting, advanced support, and education services. The company was founded by Lawrence Joseph Ellison, Robert Nimrod Miner and Edward A. Oates on June 16, 1977 and is headquartered in Redwood City, CA.", "CEO": "Safra Ada Catz / Mark V. Hurd", "securityName": "Oracle Corporation", "issueType": "cs", "sector": "Technology Services", "employees": 136000, "tags": ["Technology Services", "Packaged Software"]}')
#
# -------------------------------------------
# Time: 2021-01-19 15:07:38
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:39
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:41
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:42
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:43
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:44
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:46
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:47
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:48
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:49
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:51
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:52
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:53
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:54
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:56
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:57
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:58
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:07:59
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:00
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:01
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:02
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:03
# -------------------------------------------
# (None, '{"symbol": "AAPL", "companyName": "Apple, Inc.", "primaryExchange": "LDK TASLNGEL)A QNM(/GSSCEBA TOREA", "calculationPrice": "tops", "open": null, "openTime": null, "openSource": "aifliocf", "close": null, "closeTime": null, "closeSource": "foliiafc", "high": null, "highTime": null, "highSource": null, "low": null, "lowTime": 1645297237017, "lowSource": "Xcre la ipe IrmtieE", "latestPrice": 129.39, "latestSource": "IEX real time price", "latestTime": "10:08:02 AM", "latestUpdate": 1623319759669, "latestVolume": null, "iexRealtimePrice": 132.023, "iexRealtimeSize": 1, "iexLastUpdated": 1618425720894, "delayedPrice": null, "delayedPriceTime": null, "oddLotDelayedPrice": null, "oddLotDelayedPriceTime": null, "extendedPrice": null, "extendedChange": null, "extendedChangePercent": null, "extendedPriceTime": null, "previousClose": 127.53, "previousVolume": 115707485, "change": 0.12, "changePercent": 0.0009, "volume": null, "iexMarketPercent": 0.008402985855966121, "iexVolume": 227291, "avgTotalVolume": 110091694, "iexBidPrice": 131.44, "iexBidSize": 103, "iexAskPrice": 134, "iexAskSize": 103, "iexOpen": 131.694, "iexOpenTime": 1634670141620, "iexClose": 127.837, "iexCloseTime": 1620045737034, "marketCap": 2145956125412, "peRatio": 39.3, "week52High": 140.17, "week52Low": 55.83, "ytdChange": -0.04154505423509581, "lastTradeTime": 1682420114700, "isUSMarketOpen": true, "exchange": "NASDAQ", "industry": "Telecommunications Equipment", "website": "http://www.apple.com", "description": "Apple, Inc. engages in the design, manufacture, and marketing of mobile communication, media devices, personal computers, and portable digital music players. It operates through the following geographical segments: Americas, Europe, Greater China, Japan, and Rest of Asia Pacific. The Americas segment includes North and South America. The Europe segment consists of European countries, as well as India, the Middle East, and Africa. The Greater China segment comprises of China, Hong Kong, and Taiwan. The Rest of Asia Pacific segment includes Australia and Asian countries. The company was founded by Steven Paul Jobs, Ronald Gerald Wayne, and Stephen G. Wozniak on April 1, 1976 and is headquartered in Cupertino, CA.", "CEO": "Timothy Donald Cook", "securityName": "Apple Inc.", "issueType": "cs", "sector": "Electronic Technology", "employees": 132000, "tags": ["Electronic Technology", "Telecommunications Equipment"]}')
#
# -------------------------------------------
# Time: 2021-01-19 15:08:04
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:05
# -------------------------------------------
# (None, '{"symbol": "GOOG", "companyName": "Alphabet, Inc.", "primaryExchange": "EANE)LS QTAAKCS/GMDOGLLRE B SNT(A", "calculationPrice": "tops", "open": null, "openTime": null, "openSource": "iaiolcff", "close": null, "closeTime": null, "closeSource": "fifoailc", "high": null, "highTime": null, "highSource": null, "low": null, "lowTime": 1647021380582, "lowSource": "mrpte ciEailer  eXI", "latestPrice": 1764.82, "latestSource": "IEX real time price", "latestTime": "10:07:32 AM", "latestUpdate": 1664512093291, "latestVolume": null, "iexRealtimePrice": 1831.71, "iexRealtimeSize": 1, "iexLastUpdated": 1621024992018, "delayedPrice": null, "delayedPriceTime": null, "oddLotDelayedPrice": null, "oddLotDelayedPriceTime": null, "extendedPrice": null, "extendedChange": null, "extendedChangePercent": null, "extendedPriceTime": null, "previousClose": 1737.06, "previousVolume": 1392101, "change": 20.05, "changePercent": 0.0114, "volume": null, "iexMarketPercent": 0.06520751926492911, "iexVolume": 16611, "avgTotalVolume": 1458130, "iexBidPrice": 0, "iexBidSize": 0, "iexAskPrice": 0, "iexAskSize": 0, "iexOpen": 1762.12, "iexOpenTime": 1614936239253, "iexClose": 1816.76, "iexCloseTime": 1646720835247, "marketCap": 1215749448146, "peRatio": null, "week52High": 1903.88, "week52Low": 1080.84, "ytdChange": 0.0021819207443917387, "lastTradeTime": 1669425808414, "isUSMarketOpen": true, "exchange": "NASDAQ", "industry": "Internet Software/Services", "website": "http://abc.xyz", "description": "Alphabet, Inc. is a holding company, which engages in the business of acquisition and operation of different companies. It operates through the Google and Other Bets segments. The Google segment includes its main Internet products such as Ads, Android, Chrome, Commerce, Google Cloud, Google Maps, Google Play, Hardware, Search, and YouTube. The Other Bets segment includes businesses such as Access, Calico, CapitalG, GV, Nest, Verily, Waymo, and X. The company was founded by Lawrence E. Page and Sergey Mikhaylovich Brin on October 2, 2015 and is headquartered in Mountain View, CA.", "CEO": "Lawrence E. Page", "securityName": "Alphabet Inc. Class C", "issueType": "cs", "sector": "Technology Services", "employees": 98771, "tags": ["Technology Services", "Internet Software/Services"]}')
#
# -------------------------------------------
# Time: 2021-01-19 15:08:06
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:07
# -------------------------------------------
# (None, '{"symbol": "ORCL", "companyName": "Oracle Corp.", "primaryExchange": " T GXYNNCCENCK,.AR E ESOOKHIW", "calculationPrice": "tops", "open": null, "openTime": null, "openSource": "ialcoffi", "close": null, "closeTime": null, "closeSource": "iiofalcf", "high": null, "highTime": 1631705242054, "highSource": "d5erielui n dyeat mcep1", "low": null, "lowTime": 1637467509162, "lowSource": "eEria Xceet iIprl m", "latestPrice": 63.588, "latestSource": "IEX real time price", "latestTime": "10:07:36 AM", "latestUpdate": 1619275970448, "latestVolume": null, "iexRealtimePrice": 63.059, "iexRealtimeSize": 103, "iexLastUpdated": 1627408148557, "delayedPrice": null, "delayedPriceTime": null, "oddLotDelayedPrice": null, "oddLotDelayedPriceTime": null, "extendedPrice": null, "extendedChange": null, "extendedChangePercent": null, "extendedPriceTime": null, "previousClose": 62.5, "previousVolume": 7846317, "change": -0.138, "changePercent": -0.0023, "volume": null, "iexMarketPercent": 0.015771536685582115, "iexVolume": 28034, "avgTotalVolume": 9509822, "iexBidPrice": 62.29, "iexBidSize": 102, "iexAskPrice": 64.4, "iexAskSize": 105, "iexOpen": 62.306, "iexOpenTime": 1683969625460, "iexClose": 62.241, "iexCloseTime": 1676963211274, "marketCap": 185497408745, "peRatio": 19.18, "week52High": 67.81, "week52Low": 40.42, "ytdChange": -0.04390106790751564, "lastTradeTime": 1632004432378, "isUSMarketOpen": true, "exchange": "New York Stock Exchange", "industry": "Packaged Software", "website": "http://www.oracle.com", "description": "Oracle Corp. engages in the provision of products and services that address all aspects of corporate information technology environments. It operates through the following business segments: Cloud and License, Hardware, and Services. The Cloud and License segment markets, sells, and delivers applications, platform, and infrastructure technologies. The Hardware segment provides hardware products and hardware-related software products including Oracle Engineered Systems, servers, storage, industry-specific hardware, operating systems, virtualization, management and other hardware related software, and related hardware support. The Services segment offers consulting, advanced support, and education services. The company was founded by Lawrence Joseph Ellison, Robert Nimrod Miner and Edward A. Oates on June 16, 1977 and is headquartered in Redwood City, CA.", "CEO": "Safra Ada Catz / Mark V. Hurd", "securityName": "Oracle Corporation", "issueType": "cs", "sector": "Technology Services", "employees": 136000, "tags": ["Technology Services", "Packaged Software"]}')
#
# -------------------------------------------
# Time: 2021-01-19 15:08:08
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:09
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:10
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:11
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:12
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:13
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:14
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:15
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:16
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:17
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:18
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:19
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:20
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:21
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:22
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:23
# -------------------------------------------
#
# -------------------------------------------
# Time: 2021-01-19 15:08:24
# -------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-18f3db416f1c> in <module>
#       1 ssc.start()
# ----> 2 ssc.awaitTermination()
#
# /usr/local/spark/python/pyspark/streaming/context.py in awaitTermination(self, timeout)
#     190         """
#     191         if timeout is None:
# --> 192             self._jssc.awaitTermination()
#     193         else:
#     194             self._jssc.awaitTerminationOrTimeout(int(timeout * 1000))
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in send_command(self, command, retry, binary)
#     983         connection = self._get_connection()
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#     987                 return response, self._create_connection_guard(connection)
#
# /usr/local/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in send_command(self, command)
#    1150
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#    1154             if answer.startswith(proto.RETURN_MESSAGE):
#
# /opt/conda/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:
